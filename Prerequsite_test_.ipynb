# %% [markdown]
# 1) (k) x (n x m) multiplications and (k-1) x (n x m) additions we need to perform a matrix multiplication between a (n, k) and (k, m) matrix
#
# the process for matrix multiplication is to multiply elements of a row from first matrix to the element of second matrix, as in any row of first matrix there will be 'k' elements and any column of second matrix has 'k' elements, so we multiply 'k' times to find any element of resultant matrix.
# To find all elements(i.e., n x m) of resultant matrix, we will perform (k) x (n x m) multiplications.
# and in while finding single element we will add all those multiplied terms, so in this case we will add 'k-1' times.
# To find all elements(i.e., n x m) of resultant matrix, we will perform (k-1) x (n x m) additions.

# %%
# 2)
import time
import numpy as np
import random

def matrix_multiplication(a, b):
    r1, c1, r2, c2 = len(a), len(a[0]), len(b), len(b[0])
    
    if c1 != r2:
        return
    
    multiplied_matrix = []
    
    for i in range(r1):
        row_of_multiplied_matrix = []

        for j in range(c2):
            item = 0

            for k in range(c1):
                item = item + a[i][k]*b[k][j]

            row_of_multiplied_matrix.append(item)
        
        multiplied_matrix.append(row_of_multiplied_matrix)
    
    return multiplied_matrix


# A = [
#     [2, 1, 3, 4],
#     [0, 5, 2, 1],
#     [8, 2, 4, 6]
# ]
# B = [
#     [7, 2, 1, 5, 3],
#     [4, 0, 9, 8, 2],
#     [6, 1, 3, 7, 4],
#     [2, 5, 8, 1, 6]
# ]

A = np.random.rand(100, 100)
B = np.random.rand(100, 100)

start_time = time.time()
output = matrix_multiplication(A, B)
my_duration = time.time() - start_time

print(output)
# Out:
# [[26.89810986865459, 27.45331138860699, 24.971588422965105, 25.5258969931335, 26.83307401820149, 27.188208815805382, 26.368368465287926, 26.8953031176616, 24.91751882318843, 22.025127295971263, 30.968234600875462, 24.502456052019944, 25.46657872052738, 26.448266112838372, 23.705183333983694, 25.707455852737212, 23.954813358241818, 28.65285660248148, 27.831700912727857, 23.769589941390265, 26.248292562257664, 23.866145738688896, 26.40456844605915, 27.785447953745507, 25.483107829291427, 26.651443544721012, 27.441582437761717, 27.684964076862272, 27.321990214191324, 25.503244241817196, 23.565278782895998, 23.110672184396865, 29.299795419338675, 23.256638238847195, 27.90461179621211, 29.383928323350606, 27.790458210199276, 26.053134086164068, 27.618265849345235, 27.51695489322696, 24.948310340571023, 24.201863797070928, 25.07833674140933, 24.765684822670192, 24.487165400385877, 24.717750592022036, 28.97569179676188, 23.265530370831403, 24.642436164764984, 25.914670719565173, 27.855189710838452, 23.136465989786515, 26.176302826484754, 26.07902868781947, 26.019488563324373, 28.27563563996585, 29.04687177297835, 26.36608484293822, 27.236136253127857, 26.388985315632265, 25.589164503841086, 27.54119310013125, 27.37607395157587, 22.497743712673714, 24.074717629407544, 27.608131541548545, 25.62007835975539, 23.44766501104317, 22.95707110133561, 25.257430277508355, 24.42378879398506, 26.670089646418464, 26.555117581310405, 24.94726429584124, 25.77780239251404, 27.22136512129041, 25.42013846009048, 24.812355448190694, 24.451353791801463, 27.187592085753515, 28.55833682978678, 26.612886747084705, 26.275138
# Out:
# Time taken by the function I defined: 0.3670334815979004
# Time taken by the function in numpy library: 0.0

# %% [markdown]
# #### Numpy's function is faster

# %%
# 3)

#######--1--#######

start_time = time.time()

# lst = [40, 5, 6, 8641 ,86, 4, 8 ,56, 567, 42]
lst = [random.randint(1, 100) for _ in range(10000)]
lst_ = lst
median = lst[0]

while len(lst)>2:
    max = lst[0]
    for i in range(1, len(lst)):
        if lst[i]>max:
            max = lst[i]
    lst.remove(max)
    min = lst[0]
    for i in range(1, len(lst)):
        if lst[i]<min:
            min = lst[i]
    lst.remove(min)
        
if len(lst)==2:
    median = (lst[0]+lst[1])/2
else:
    median = lst[0]
    
print(median)

first_method_duration = time.time() - start_time
# Out:
# 50.0

# %%
#######--2--#######

start_time = time.time()

# lst = [40, 5, 6, 8641 ,86, 4, 8 ,56, 567, 42]
lst_sorted = lst_.sort()

if len(lst)%2==1:
    median = lst[len(lst)//2]
else:
    median = (lst[len(lst)//2]+lst[(len(lst)//2)-1])/2
    
print(median)

second_method_duration = time.time() - start_time
# Out:
# 50.0

# %%
start_time = time.time()

np_median = np.median(lst_)
print(np_median)

numpy__duration = time.time() - start_time
# Out:
# 50.0

# %%
print("Time taken by first method: ", first_method_duration)
print("Time taken by second method: ", second_method_duration)
print("Time taken by numpy function: ", numpy__duration)
# Out:
# Time taken by first method:  2.4628360271453857
# Time taken by second method:  0.0
# Time taken by numpy function:  0.0012936592102050781

# %% [markdown]
# 4) Gradient of (x^2).y + (y^3).(sin(x)) is [ 2.x.y + (y^3)(cos(x))  , (x^2) + (3.(y^2).(sin(x)) ]

# %%
# 5)

import jax
import jax.numpy as jnp
import math

# Define a mathematical equation as a function
def equation(x, y):
    return ((x**2) * y) + ((y**3) * (jax.numpy.sin(x)))

# Create JAX arrays as input
x, y = jnp.array([math.pi, 1.0])

# Compute the gradient of the equation with respect to the input array
grad_equation = jax.grad(equation, argnums=(0, 1))(x, y)

print("Gradient of the equation:", grad_equation)
# Out:
# Gradient of the equation: (Array(5.2831855, dtype=float32), Array(9.869605, dtype=float32))

# %%
# 7)

student_records = {
    2022: {
        'Branch 1': {
            1: {'Name': 'Sai', 'Marks': {'Maths': 100, 'English': 70}},
        },
        'Branch 2': {

        },
    },
    2023: {
        'Branch 1': {

        },
        'Branch 2': {

        },
    },
    2024: {
        'Branch 1': {

        },
        'Branch 2': {

        },
    }

}

# %%
# 8)

class Student:
    def __init__(self, roll_number, name, marks):
        self.roll_number = roll_number
        self.name = name
        self.marks = marks


class Branch:
    def __init__(self, name):
        self.name = name
        self.students = []

    def add_student(self, student):
        self.students.append(student)


class Year:
    def __init__(self, year):
        self.year = year
        self.branches = []

    def add_branch(self, branch):
        self.branches.append(branch)

# %%
# 9)

x = np.arange(0.5, 100, 0.5)
print(x)
# Out:
# [ 0.5  1.   1.5  2.   2.5  3.   3.5  4.   4.5  5.   5.5  6.   6.5  7.
#   7.5  8.   8.5  9.   9.5 10.  10.5 11.  11.5 12.  12.5 13.  13.5 14.
#  14.5 15.  15.5 16.  16.5 17.  17.5 18.  18.5 19.  19.5 20.  20.5 21.
#  21.5 22.  22.5 23.  23.5 24.  24.5 25.  25.5 26.  26.5 27.  27.5 28.
#  28.5 29.  29.5 30.  30.5 31.  31.5 32.  32.5 33.  33.5 34.  34.5 35.
#  35.5 36.  36.5 37.  37.5 38.  38.5 39.  39.5 40.  40.5 41.  41.5 42.
#  42.5 43.  43.5 44.  44.5 45.  45.5 46.  46.5 47.  47.5 48.  48.5 49.
#  49.5 50.  50.5 51.  51.5 52.  52.5 53.  53.5 54.  54.5 55.  55.5 56.
#  56.5 57.  57.5 58.  58.5 59.  59.5 60.  60.5 61.  61.5 62.  62.5 63.
#  63.5 64.  64.5 65.  65.5 66.  66.5 67.  67.5 68.  68.5 69.  69.5 70.
#  70.5 71.  71.5 72.  72.5 73.  73.5 74.  74.5 75.  75.5 76.  76.5 77.
#  77.5 78.  78.5 79.  79.5 80.  80.5 81.  81.5 82.  82.5 83.  83.5 84.
#  84.5 85.  85.5 86.  86.5 87.  87.5 88.  88.5 89.  89.5 90.  90.5 91.
#  91.5 92.  92.5 93.  93.5 94.  94.5 95.  95.5 96.  96.5 97.  97.5 98.
#  98.5 99.  99.5]

# %%
import matplotlib.pyplot as plt

y1 = x
plt.plot(x, y1)
plt.show()

# %%
y1 = x**2
plt.plot(x, y1)
plt.show()

# %%
y1 = x**3/3
plt.plot(x, y1)
plt.show()

# %%
y1 = np.sin(x)
plt.plot(x, y1)
plt.show()

# %%
y1 = (np.sin(x))/x
plt.plot(x, y1)
plt.show()

# %%
y1 = np.log(x)
plt.plot(x, y1)
plt.show()

# %%
y1 = np.exp(x)
plt.plot(x, y1)
plt.show()

# %%
# 10)

import numpy as np

matrix = np.random.uniform(1, 2, size=(20, 5))
print(matrix)
# Out:
# [[1.37023523 1.24711271 1.46457983 1.37079692 1.44388404]
#  [1.21585311 1.83823721 1.08729877 1.54574543 1.62171101]
#  [1.06345657 1.76259202 1.04496598 1.78818939 1.78694944]
#  [1.22464247 1.45234647 1.77240303 1.89687686 1.85110724]
#  [1.30680695 1.27063675 1.52236888 1.18345398 1.48613157]
#  [1.71559029 1.04998081 1.6104267  1.43785097 1.88555131]
#  [1.38478249 1.99044451 1.30805012 1.8718652  1.01421477]
#  [1.14618088 1.281752   1.89711986 1.40909586 1.63660736]
#  [1.7763551  1.79967141 1.36742471 1.9308302  1.50245966]
#  [1.67680838 1.23977709 1.12757178 1.07671349 1.62846791]
#  [1.40504267 1.922768   1.02231176 1.71352385 1.66053267]
#  [1.12921773 1.23505547 1.11347147 1.1962437  1.98440343]
#  [1.84945956 1.8445067  1.77270228 1.20928904 1.22830975]
#  [1.7846783  1.32465574 1.91781783 1.84640136 1.40226616]
#  [1.2364647  1.48418647 1.02620987 1.77537899 1.70069211]
#  [1.96432967 1.57590242 1.04265898 1.95920155 1.20772594]
#  [1.82838681 1.43363298 1.37241983 1.07871129 1.36817701]
#  [1.79178197 1.34756346 1.85417742 1.77967733 1.30439006]
#  [1.89750935 1.8769247  1.18706263 1.37789997 1.51797322]
#  [1.08719739 1.9303202  1.71765517 1.89716932 1.13238252]]

# %%
import pandas as pd
df = pd.DataFrame(matrix, columns=["a", "b", "c", "d", "e"])
df
# Out:
#            a         b         c         d         e
# 0   1.370235  1.247113  1.464580  1.370797  1.443884
# 1   1.215853  1.838237  1.087299  1.545745  1.621711
# 2   1.063457  1.762592  1.044966  1.788189  1.786949
# 3   1.224642  1.452346  1.772403  1.896877  1.851107
# 4   1.306807  1.270637  1.522369  1.183454  1.486132
# 5   1.715590  1.049981  1.610427  1.437851  1.885551
# 6   1.384782  1.990445  1.308050  1.871865  1.014215
# 7   1.146181  1.281752  1.897120  1.409096  1.636607
# 8   1.776355  1.799671  1.367425  1.930830  1.502460
# 9   1.676808  1.239777  1.127572  1.076713  1.628468
# 10  1.405043  1.922768  1.022312  1.713524  1.660533
# 11  1.129218  1.235055  1.113471  1.196244  1.984403
# 12  1.849460  1.844507  1.772702  1.209289  1.228310
# 13  1.784678  1.324656  1.917818  1.846401  1.402266
# 14  1.236465  1.484186  1.026210  1.775379  1.700692
# 15  1.964330  1.575902  1.042659  1.959202  1.207726
# 16  1.828387  1.433633  1.372420  1.078711  1.368177
# 17  1.791782  1.347563  1.854177  1.779677  1.304390
# 18  1.897509  1.876925  1.187063  1.377900  1.517973
# 19  1.087197  1.930320  1.717655  1.897169  1.132383

# %%
column_std = df.std()
column_std
# Out:
# a    0.311948
# b    0.296330
# c    0.324984
# d    0.311341
# e    0.261328
# dtype: float64

# %%
print("Highest Standard Deviation: ", np.max(column_std))
max_std_column = column_std.idxmax()
print("Column with Highest Standard Deviation: ", max_std_column)
# Out:
# Highest Standard Deviation:  0.3249835077914188
# Column with Highest Standard Deviation:  c

# %%
row_mean = df.mean(axis=1)
row_mean
# Out:
# 0     1.379322
# 1     1.461769
# 2     1.489231
# 3     1.639475
# 4     1.353880
# 5     1.539880
# 6     1.513871
# 7     1.474151
# 8     1.675348
# 9     1.349868
# 10    1.544836
# 11    1.331678
# 12    1.580853
# 13    1.655164
# 14    1.444586
# 15    1.549964
# 16    1.416266
# 17    1.615518
# 18    1.571474
# 19    1.552945
# dtype: float64

# %%
np.min(row_mean)
print("Lowest Mean: ", np.min(row_mean))
min_mean_row = row_mean.idxmin()
print("Row with lowest Mean: ", min_mean_row)
# Out:
# Lowest Mean:  1.3316783596125898
# Row with lowest Mean:  11

# %%
# 11)

df["f"] = df.sum(axis=1)
df
# Out:
#            a         b         c         d         e         f
# 0   1.370235  1.247113  1.464580  1.370797  1.443884  6.896609
# 1   1.215853  1.838237  1.087299  1.545745  1.621711  7.308846
# 2   1.063457  1.762592  1.044966  1.788189  1.786949  7.446153
df
# Out:
#            a         b         c         d         e         f    g
# 0   1.370235  1.247113  1.464580  1.370797  1.443884  6.896609  LT8
# 1   1.215853  1.838237  1.087299  1.545745  1.621711  7.308846  LT8
# 2   1.063457  1.762592  1.044966  1.788189  1.786949  7.446153  LT8
# 3   1.224642  1.452346  1.772403  1.896877  1.851107  8.197376  GT8
# 4   1.306807  1.270637  1.522369  1.183454  1.486132  6.769398  LT8
# 5   1.715590  1.049981  1.610427  1.437851  1.885551  7.699400  LT8
# 6   1.384782  1.990445  1.308050  1.871865  1.014215  7.569357  LT8
# 7   1.146181  1.281752  1.897120  1.409096  1.636607  7.370756  LT8
# 8   1.776355  1.799671  1.367425  1.930830  1.502460  8.376741  GT8
# 9   1.676808  1.239777  1.127572  1.076713  1.628468  6.749339  LT8
# 10  1.405043  1.922768  1.022312  1.713524  1.660533  7.724179  LT8
# 11  1.129218  1.235055  1.113471  1.196244  1.984403  6.658392  LT8
# 12  1.849460  1.844507  1.772702  1.209289  1.228310  7.904267  LT8
# 13  1.784678  1.324656  1.917818  1.846401  1.402266  8.275819  GT8
# 14  1.236465  1.484186  1.026210  1.775379  1.700692  7.222932  LT8
# 15  1.964330  1.575902  1.042659  1.959202  1.207726  7.749819  LT8
# 16  1.828387  1.433633  1.372420  1.078711  1.368177  7.081328  LT8
# 17  1.791782  1.347563  1.854177  1.779677  1.304390  8.077590  GT8
# 18  1.897509  1.876925  1.187063  1.377900  1.517973  7.857370  LT8
# 19  1.087197  1.930320  1.717655  1.897169  1.132383  7.764725  LT8

# %%
lt8 = df[df["g"]=="LT8"]
lt8_ = lt8.drop(["g"], axis=1)
lt8_std = lt8_.std(axis=1)
lt8_std
# Out:
# 0     2.253713
# 1     2.402720
# 2     2.457729
# 4     2.214675
# 5     2.530698
# 6     2.498855
# 7     2.421944
# 9     2.218824
# 10    2.541554
# 11    2.199419
# 12    2.598543
# 14    2.375682
# 15    2.559147
# 16    2.325185
# 18    2.581270
# 19    2.562694
# dtype: float64

# %%
gt8 = df[df["g"]=="GT8"]
gt8_ = gt8.drop(["g"], axis=1)
gt8_std = gt8_.std(axis=1)
gt8_std
# Out:
# 3     2.689766
# 8     2.743703
# 13    2.713783
# 17    2.648857
# dtype: float64

# %% [markdown]
# 12) Boardcasting: when we multiply a matrix with scalar value, numpy creates a same shaped matrix as given matrix containing the scalar value in all places and then multiplies both matrices
# In other sense it multiplies the scalar value with all elements of matrix

# %%
Matrix = np.array([[1, 5, 6], [6, 7, 4], [8, 1, 3]])
Matrix*5
# Out:
# array([[ 5, 25, 30],
#        [30, 35, 20],
#        [40,  5, 15]])

# %%
# 13)

def arg_min(lst):
    min = lst[0]
    min_ind = 0
    for i in range(1, len(lst)):
        if lst[i]<min:
            min = lst[i]
            min_ind = i
            
    return min_ind

lst = np.array([5, 6, 8, 1, 9, 2])
arg_min(lst)
# Out:
# 3

# %%
np.argmin(lst)
# Out:
# 3
